# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.boxplot(column='SepalWidthCm')
# Out:
# <Axes: >

# %%
df.boxplot(column='SepalLengthCm')
# Out:
# <Axes: >

# %%
plt.boxplot(data=df,x='SepalLengthCm')
plt.show()

# %%
plt.boxplot(data=df,x='SepalWidthCm')
plt.show()

# %%
sns.histplot(data=df,x='Species',y='SepalLengthCm',multiple='stack')
plt.show()

# %%
sns.scatterplot(data=df, x="Species", y="SepalLengthCm")
plt.show()

# %%
df.boxplot(column='SepalLengthCm',by='Species')
plt.show()

# %%
df.boxplot(column='SepalWidthCm',by='Species')
plt.show()

# %%
sns.histplot(data=df,y='SepalWidthCm')
plt.show()

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           2.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
